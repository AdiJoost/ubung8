# %%
import pandas as pd


earthquick = pd.read_csv('data\earthquakes.txt', sep=' ', header=None)
earthquick.rename(columns={0: 'date', 1: 'time'}, inplace=True)
earthquick.rename(columns={2: 'lat'}, inplace=True)
earthquick.rename(columns={3: 'latd'}, inplace=True)
earthquick.rename(columns={4: 'long'}, inplace=True)
earthquick.rename(columns={5: 'longd'}, inplace=True)
earthquick.rename(columns={6: 'depth'}, inplace=True)
earthquick.rename(columns={7: 'mag'}, inplace=True)
earthquick
# Out:
#              date   time    lat latd   long longd depth  mag
# 0      2017-02-22  15:10  23.93    S  67.34     W   233  3.5
# 1      2017-02-22  14:56  47.30    N  23.79     E   3</  2.6
# 2      2017-02-22  14:49  21.51    S  67.15     W   234  3.3
# 3      2017-02-22  14:03  6.56&    N  73.50     W   113  3.6
# 4      2017-02-22  13:41  39.52    N  26.06     E   16<  2.1
# ...           ...    ...    ...  ...    ...   ...   ...  ...
# 49944  2016-03-11  00:38  32.78    S  71.05     W   67<  2.6
# 49945  2016-03-11  00:26  36.08    N  27.49     E   9</  2.2
# 49946  2016-03-11  00:11  37.57    N  118.8     W   5</  2.0
# 49947  2016-03-11  00:06  36.63    N  27.01     E   126  2.3
# 49948  2016-03-10  23:53  76.91    N  18.34     E   15<  2.2
#
# [49949 rows x 8 columns]

# %%
earthquick['date'] = pd.to_datetime(earthquick['date'] + ' ' + earthquick['time'])
earthquick.drop(columns=['time'], inplace=True)
earthquick
earthquick.to_csv('data\earthquakes.csv', index=False)

# %%
earthquick.head()
# Out:
#                  date    lat latd   long longd depth  mag
# 0 2017-02-22 15:10:00  23.93    S  67.34     W   233  3.5
# 1 2017-02-22 14:56:00  47.30    N  23.79     E   3</  2.6
# 2 2017-02-22 14:49:00  21.51    S  67.15     W   234  3.3
# 3 2017-02-22 14:03:00  6.56&    N  73.50     W   113  3.6
# 4 2017-02-22 13:41:00  39.52    N  26.06     E   16<  2.1

# %%
earthquick.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49949 entries, 0 to 49948
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    49949 non-null  datetime64[ns]
#  1   lat     49949 non-null  object
#  2   latd    49949 non-null  object
#  3   long    49949 non-null  object
#  4   longd   49949 non-null  object
#  5   depth   49949 non-null  object
#  6   mag     49949 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(5)
# memory usage: 2.7+ MB

# %%
earthquick['lat'] = earthquick['lat'].str.replace('&', '')
earthquick['long'] = earthquick['long'].str.replace('&', '')
earthquick['depth'] = earthquick['depth'].str.replace('</', '')
earthquick['depth'] = earthquick['depth'].str.replace('<', '')


earthquick['long'] = earthquick['long'].astype(float)
earthquick['lat'] = earthquick['lat'].astype(float)
earthquick['depth'] = earthquick['depth'].astype(float)
earthquick.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49949 entries, 0 to 49948
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    49949 non-null  datetime64[ns]
#  1   lat     49949 non-null  float64
#  2   latd    49949 non-null  object
#  3   long    49949 non-null  float64
#  4   longd   49949 non-null  object
#  5   depth   49949 non-null  float64
#  6   mag     49949 non-null  float64
# dtypes: datetime64[ns](1), float64(4), object(2)
# memory usage: 2.7+ MB

# %%
#  filter on magnitude
filtermag = earthquick['mag'] > 2.0 
earthquick[filtermag]
# Out:
#                      date    lat latd    long longd  depth  mag
# 0     2017-02-22 15:10:00  23.93    S   67.34     W  233.0  3.5
# 1     2017-02-22 14:56:00  47.30    N   23.79     E    3.0  2.6
# 2     2017-02-22 14:49:00  21.51    S   67.15     W  234.0  3.3
# 3     2017-02-22 14:03:00   6.56    N   73.50     W  113.0  3.6
# 4     2017-02-22 13:41:00  39.52    N   26.06     E   16.0  2.1
# ...                   ...    ...  ...     ...   ...    ...  ...
# 49943 2016-03-11 00:49:00  64.74    N  145.60     W   15.0  2.5
# 49944 2016-03-11 00:38:00  32.78    S   71.05     W   67.0  2.6
# 49945 2016-03-11 00:26:00  36.08    N   27.49     E    9.0  2.2
# 49947 2016-03-11 00:06:00  36.63    N   27.01     E  126.0  2.3
# 49948 2016-03-10 23:53:00  76.91    N   18.34     E   15.0  2.2
#
# [45326 rows x 7 columns]

# %%
filterdepth = earthquick['depth'] < 0
earthquick[filterdepth]
# Out:
#                      date    lat latd  long longd  depth  mag
# 1369  2017-02-13 14:59:00  47.45    N  8.10     E   -1.0  1.8
# 5032  2017-01-23 08:31:00  47.21    N  7.17     E   -1.0  1.8
# 5949  2017-01-17 05:54:00  47.10    N  9.11     E   -1.0  1.7
# 9340  2016-12-22 21:06:00  46.36    N  6.76     E   -2.0  1.7
# 9893  2016-12-18 11:00:00  46.97    N  8.84     E   -1.0  2.0
# 9921  2016-12-18 07:34:00  46.97    N  8.84     E   -2.0  2.0
# 15283 2016-11-12 10:39:00  46.25    N  6.95     E   -1.0  2.1
# 16795 2016-11-02 13:57:00  46.23    N  6.98     E   -1.0  1.5
# 19392 2016-10-20 08:36:00  46.91    N  8.34     E   -2.0  1.5
# 20303 2016-10-13 08:00:00  47.45    N  8.10     E   -1.0  1.5
# 20422 2016-10-12 11:29:00  46.23    N  6.99     E   -1.0  1.5
# 22046 2016-09-30 12:00:00  46.23    N  6.98     E   -1.0  1.5
# 22175 2016-09-29 13:19:00  47.71    N  7.81     E   -1.0  1.6
# 22411 2016-09-28 04:48:00  47.22    N  9.98     E   -2.0  1.9
# ...
